# %%
# %run "plot_results-figure3.ipynb"
# %run "plot_results-figure4.ipynb"
# %run "plot_results-figure5.ipynb"

# %%
fig, axs = plt.subplots(1, 3, figsize=(16,3))

axs[0].plot(list_auxLOSPR, SNR_SER_DFR[0], '-o', linewidth=2.0, label= '4 QAM w/ DFR')
axs[0].plot(list_auxLOSPR, SNR_SER_IC[0], '-o', linewidth=2.0, label= '4 QAM w/ IC')
axs[0].plot(list_auxLOSPR, SNR_SER_GD[0], '-o', linewidth=2.0, label= '4 QAM w/ GD')
axs[0].set_ylabel('SNR (dB)', fontsize=12.0, fontweight='bold')
axs[0].set_xlabel('LOSPR (dB)', fontsize=12.0, fontweight='bold')
axs[0].legend(loc='lower right', fontsize=11.0)
axs[0].set_ylim(14,45)
for tick in axs[0].yaxis.get_ticklabels():
    tick.set_fontweight('bold')
for tick in axs[0].xaxis.get_ticklabels():
    tick.set_fontweight('bold')
axs[0].grid()

axs[1].plot(list_auxLOSPR, SNR_SER_DFR[1], '-o', linewidth=2.0, label= '16 QAM w/ DFR')
axs[1].plot(list_auxLOSPR, SNR_SER_IC[1], '-o', linewidth=2.0, label= '16 QAM w/ IC')
axs[1].plot(list_auxLOSPR, SNR_SER_GD[1], '-o', linewidth=2.0, label= '16 QAM w/ GD')
axs[1].set_ylabel('SNR (dB)', fontsize=12.0, fontweight='bold')
axs[1].set_xlabel('LOSPR (dB)', fontsize=12.0, fontweight='bold')
axs[1].legend(loc='lower right', fontsize=11.0)
axs[1].set_ylim(14,45)
for tick in axs[1].yaxis.get_ticklabels():
    tick.set_fontweight('bold')
for tick in axs[1].xaxis.get_ticklabels():
    tick.set_fontweight('bold')
axs[1].grid()

axs[2].plot(list_auxLOSPR, SNR_SER_DFR[2], '-o', linewidth=2.0, label= '64 QAM w/ DFR')
axs[2].plot(list_auxLOSPR, SNR_SER_IC[2], '-o', linewidth=2.0, label= '64 QAM w/ IC')
axs[2].plot(list_auxLOSPR, SNR_SER_GD[2], '-o', linewidth=2.0, label= '64 QAM w/ GD')
axs[2].set_ylabel('SNR (dB)', fontsize=12.0, fontweight='bold')
axs[2].set_xlabel('LOSPR (dB)', fontsize=12.0, fontweight='bold')
axs[2].legend(loc='lower right', fontsize=11.0)
axs[2].set_ylim(14,45)
for tick in axs[2].yaxis.get_ticklabels():
    tick.set_fontweight('bold')
for tick in axs[2].xaxis.get_ticklabels():
    tick.set_fontweight('bold')
axs[2].grid()
