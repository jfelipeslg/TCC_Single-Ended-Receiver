# %%
# %reset -f

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.constants as const
import pandas as pd
import cmath

from commpy.modulation import QAMModem, PSKModem

from optic.core import parameters
from optic.tx import simpleWDMTx
from optic.plot import pconst

from optic.models import linFiberCh, manakovSSF, ssfm, linFiberCh, awgn
from optic.models import phaseNoise, coherentReceiver, pdmCoherentReceiver, hybrid_2x4_90deg, pbs

from optic.dsp import pulseShape, firFilter, decimate, symbolSync, pnorm
from optic.equalization import edc, mimoAdaptEqualizer
from optic.carrierRecovery import cpr
from optic.metrics import fastBERcalc, monteCarloGMI, monteCarloMI, signal_power

import logging as logg
logg.getLogger().setLevel(logg.INFO)
logg.basicConfig(format='%(message)s')

# %%
import importlib.util

# Import OFE.py (Optical Front-End)
spec = importlib.util.spec_from_file_location("OFE", "../../utils/OFE.py")
OFE = importlib.util.module_from_spec(spec)
spec.loader.exec_module(OFE)

# Import mitigationSBBI.py
spec_2 = importlib.util.spec_from_file_location("mitigationSSBI", "../../utils/mitigationSSBI.py")
SSBI = importlib.util.module_from_spec(spec_2)
spec_2.loader.exec_module(SSBI)

# %%
# Parâmetros - Transmissor
paramTx = parameters()

paramTx.M   = 64             # Ordem do formato de modulação
paramTx.constType = 'qam'   # Formato de modulação ('qam' ou 'psk')

paramTx.Rs  = 100e9         # Taxa de sinalização [baud]
paramTx.SpS = 4             # Número de amostras por símbolo
Fs = paramTx.Rs*paramTx.SpS # Taxa de amostragem [Hz]

paramTx.Nbits = 300000      # Número total de bits por polarização

paramTx.pulse    = 'rrc'    # Tipo do filtro formatador de pulso
paramTx.Ntaps    = 1024     # Número de coeficientes do filtro
paramTx.alphaRRC = 0.01     # Rolloff do pulso RRC

paramTx.Pch_dBm  = 0        # Potência média por canal WDM [dBm]
paramTx.Nch      = 1        # Número de canais WDM

paramTx.Fc     = 193.1e12   # Frequência central de operação
paramTx.Nmodes = 1          # Número de modos de polarização

# gera sinal WDM
sigWDM_Tx, symbTx_, paramTx = simpleWDMTx(paramTx)
pconst(sigWDM_Tx)
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]
# channel 0	 fc : 193.1000 THz
#   mode #0	 power: 0.00 dBm
# channel 0	 power: 0.00 dBm
#
# total WDM signal power: 0.00 dBm
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot: xlabel='In-Phase (I)', ylabel='Quadrature (Q)'>)

# %%
# Parâmetros - Canal Óptico
paramCh = parameters()

paramCh.Ltotal = 160       # Distância total do enlace [km]
paramCh.alpha = 0          # Parâmetro de perda da fibra [dB/km]
paramCh.D = 16             # Parâmetro de dispersão da fibra [ps/nm/km]
paramCh.Fc = paramTx.Fc    # Frequência central de operação [Hz]
paramCh.Fs = Fs            # Taxa de amostragem [Hz]

sigWDM = linFiberCh(sigWDM_Tx, paramCh.Ltotal, paramCh.alpha, paramCh.D, paramCh.Fc, paramCh.Fs)

# %%
# Potência do sinal recebido
try:
    potRx  = 10*np.log10( 1e3 * (signal_power(sigWDM[:,0]) + signal_power(sigWDM[:,1])) )
except:
    potRx  = 10*np.log10( 1e3 * signal_power(sigWDM))
print(f'Potência do sinal recebido: {potRx:.2f} dBm')
# Out:
# Potência do sinal recebido: -0.00 dBm

# %%
# Canal AWGN
status_awgn = True  # Ativação do AWGN
OSNRdB      = 34    # OSNR do sistema

if status_awgn:
    SNRdB  = OSNRdB - 10 * np.log10( (paramTx.Rs * paramTx.Nmodes) / (2 * 12.5e9) )
    sigWDM = awgn( sigWDM, SNRdB, Fs, paramTx.Rs)

    # Potência do sinal recebido + Potência do ruído [dBm]
    try:
        potRx_AWGN  = 10*np.log10( 1e3 * (signal_power(sigWDM[:,0]) + signal_power(sigWDM[:,1])) )
    except:
        potRx_AWGN  = 10*np.log10( 1e3 * signal_power(sigWDM) )
    print(f'Potência do sinal recebido + Potência do ruído: {potRx_AWGN:.4f} dBm')
# Out:
# Potência do sinal recebido + Potência do ruído: 0.0279 dBm

# %%
# plot psd
plt.figure(figsize=(10, 3))

plt.psd(sigWDM_Tx[:,0], Fs=Fs, Fc=paramTx.Fc, NFFT = 4*1024, sides='twosided', label = 'WDM spectrum - Tx')
plt.psd(sigWDM, Fs=Fs, Fc=paramCh.Fc, NFFT = 4*1024, sides='twosided', label = 'WDM spectrum - Rx')
plt.xlim(paramTx.Fc-Fs/2,paramTx.Fc+Fs/2)
plt.legend(loc='lower left')
plt.title('optical WDM spectrum - Mode 0')
plt.grid('True')

# %%
#############################################
# Parâmetros - Receptor
mod = QAMModem(m=paramTx.M)

chIndex  = 0     # Posição do canal WDM a ser demodulado
Fc = paramTx.Fc
Ts = 1/Fs

freqGrid = paramTx.freqGrid
print(f'Demodulating channel #{chIndex} \n',
      f'- fc: {((Fc + freqGrid[chIndex])/1e12):.4f} THz\n',
      f'- λ: {(const.c/(Fc + freqGrid[chIndex])/1e-9):.4f} nm\n')

symbTx = symbTx_[:,:,chIndex]

#############################################
# Parâmetros - Receptor - Oscilador Local
LOSPR   = 8                     # Relação potência do sinal-LO [dB]

π       = np.pi
FO      = 0*64e6                # Offset de frequência
Δf_lo   = freqGrid[chIndex]+FO  # Deslocamento de frequência do canal a ser demodulado
lw      = 0*100e3               # LineWidth
Plo_dBm = potRx + LOSPR         # Potência [dBm]
Plo     = 10**(Plo_dBm/10)*1e-3 # Potência [W]
ϕ_lo    = 0                     # Fase inicial [rad]    

print(f'Local oscillator\n',
      f'- Power: {Plo_dBm:.2f} dBm\n',
      f'- LOSPR: {LOSPR:.2f} dBm\n',
      f'- LineWidth: {(lw/1e3):.2f} kHz\n',
      f'- Frequency offset: {(FO/1e6):.2f} MHz')

#############################################
# Geração do sinal LO
t       = np.arange(0, len(sigWDM))*Ts
ϕ_pn_lo = phaseNoise(lw, len(sigWDM), Ts)
sigLO   = np.sqrt(Plo)*np.exp(1j*(2*π*Δf_lo*t + ϕ_lo + ϕ_pn_lo))
# Out:
# Demodulating channel #0
#  - fc: 193.1000 THz
#  - λ: 1552.5244 nm
#
# Local oscillator
#  - Power: 8.00 dBm
#  - LOSPR: 8.00 dBm
#  - LineWidth: 0.00 kHz
#  - Frequency offset: 0.00 MHz

# %%
# Receptor óptico
paramRx = parameters()
paramRx.type    = 'ser'  # 'br','ser'
paramRx.algSSBI = 'ic' # 'none', 'dfr', 'ic', 'gd'

# %%
assert paramRx.type in ['ser', 'br'], "Topologia de receptor inválida."

if paramRx.type == 'br':
    # Receptor óptico balanceado
    paramPD = parameters()
    paramPD.B = paramTx.Rs
    paramPD.Fs = Fs    
    paramPD.ideal = True

    sigBR = coherentReceiver(sigWDM, sigLO, paramPD=paramPD)

    sigRx = sigBR
    
else:
    # Receptor óptico single-ended
    sigWDM = sigWDM.reshape(len(sigWDM),)

    paramPD = parameters()
    paramPD.B = 2 * paramTx.Rs
    paramPD.Fs = Fs
    paramPD.ideal = True

    R1, R2 = OFE.SEReceiver(sigWDM, sigLO, paramPD)

# %%
if paramRx.type == 'ser':
    assert paramRx.algSSBI in ['none', 'dfr', 'ic', 'gd'], "Algoritmo de mitigação da SSBI inválido."
    
    if paramRx.algSSBI == 'dfr':
        # Algoritmo de reconstrução de sinal (DFR)
        sigDFR = SSBI.DFR(R1, R2, sigLO)
        sigDFR = sigDFR - np.mean(sigDFR)

        sigRx = sigDFR

    elif paramRx.algSSBI == 'ic':
        # Algoritmo iterativo de cancelamento da SSBI com clipping (IC)
        Nsteps     = 20    # Número de iterações
        enableClip = True   # Ativação o clipping
        sigIC = SSBI.IC( R1, R2, sigWDM, sigLO, N=Nsteps, clipping=enableClip)
        
        sigRx = sigIC
        
    elif paramRx.algSSBI == 'gd':
        # Algoritmo gradiente descendente (GD)
        mu_        = 0.05    # Passo do algoritmo
        Nsteps     = 120     # Número de iterações
        enableClip = True   # Ativação o clipping
        sigGD = SSBI.gradientDescent(R1, R2, sigWDM, sigLO, mu=mu_, N=Nsteps, clipping=enableClip)
        
        sigRx = sigGD

    else:
        # Não há mitigação da SSBI
        sigPD = R1 + 1j*R2
        sigPD = sigPD - np.mean(sigPD)
        
        sigRx = sigPD
        
# plot constellations (pós-receptor coerente)
pconst(sigRx[0::paramTx.SpS], lim=False, R=3, pType='fast')
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot: xlabel='In-Phase (I)', ylabel='Quadrature (Q)'>)

# %%
# Filtro casado
pulse = pulseShape('rrc', paramTx.SpS, N=paramTx.Ntaps, alpha=paramTx.alphaRRC, Ts=1/paramTx.Rs)
pulse = pulse/np.max(np.abs(pulse))

sigRx = firFilter(pulse, sigRx)
    
# plot constellations (pós-filtragem)
pconst(sigRx[0::paramTx.SpS], lim=False, R=3)

# Compensação da disperção cromática
if paramCh.Ltotal:
    sigRx = edc(sigRx, paramCh.Ltotal, paramCh.D, Fc-Δf_lo, Fs)
    
    # plot constellations (pós-filtragem+compensação)
    pconst(sigRx[0::paramTx.SpS], lim=False, R=3)

# %%
# Redução de amostras por símbolos
paramDec = parameters()

paramDec.SpS_in  = paramTx.SpS
paramDec.SpS_out = 2

sigRx = sigRx.reshape(len(sigRx), 1)
sigRx = decimate(sigRx, paramDec)
symbRx = symbolSync(sigRx, symbTx, 2)

# %%
# Normalização do sinal
x = sigRx
d = symbRx

x = x.reshape(len(x),1)/np.sqrt(signal_power(x))
d = d.reshape(len(d),1)/np.sqrt(signal_power(d))

# %%
# Algoritmo de Equalização
paramEq = parameters()
paramEq.nTaps = 15
paramEq.SpS   = 2
paramEq.mu    = [3e-3, 4e-3]
paramEq.numIter = 5
paramEq.storeCoeff = False
paramEq.alg   = ['nlms','da-rde']
paramEq.M     = paramTx.M
paramEq.L = [int(0.20*len(x)/2), int(0.80*len(x)/2)]

paramEq.prgsBar = False
y_EQ, H, errSq, Hiter = mimoAdaptEqualizer(x, dx=d, paramEq=paramEq)

# plot constellations (pós-equalização)
discard = 5000
pconst(y_EQ[discard:-discard])
# Out:
# nlms - training stage #0
# nlms pre-convergence training iteration #0
# nlms MSE = 0.004233.
# nlms pre-convergence training iteration #1
# nlms MSE = 0.004234.
# nlms pre-convergence training iteration #2
# nlms MSE = 0.004234.
# nlms pre-convergence training iteration #3
# nlms MSE = 0.004234.
# nlms pre-convergence training iteration #4
# nlms MSE = 0.004234.
# da-rde - training stage #1
# da-rde MSE = 0.009897.
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot: xlabel='In-Phase (I)', ylabel='Quadrature (Q)'>)

# %%
# Algoritmo de Recuperação de Fase
paramCPR = parameters()
paramCPR.alg = 'bps'
paramCPR.M   = paramTx.M
paramCPR.N   = 160
paramCPR.B   = 64
paramCPR.pilotInd = np.arange(0, len(y_EQ), 20) 

y_CPR, θ = cpr(y_EQ, symbTx=d, paramCPR=paramCPR)
y_CPR = y_CPR/np.sqrt(signal_power(y_CPR))

plt.figure(figsize=(10, 3))
plt.title('CPR estimated phase')
plt.plot(θ,'-')
plt.xlim(0, len(θ))
plt.grid()

# plot constellations (pós-CPR)
discard = 5000
pconst(y_CPR[discard:-discard])
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <AxesSubplot: xlabel='In-Phase (I)', ylabel='Quadrature (Q)'>)

# %%
# métricas
for k in range(y_CPR.shape[1]):
    rot = np.mean(d[:,k]/y_CPR[:,k])
    y_CPR[:,k] = rot*y_CPR[:,k]

y_CPR = y_CPR/np.sqrt(signal_power(y_CPR))


ind = np.arange(discard, d.shape[0]-discard)
BER, SER, SNR = fastBERcalc(y_CPR[ind,:], d[ind,:], paramTx.M, 'qam')
GMI,_    = monteCarloGMI(y_CPR[ind,:], d[ind,:], paramTx.M, 'qam')
MI       = monteCarloMI(y_CPR[ind,:], d[ind,:], paramTx.M, 'qam')

polx = [BER[0],SER[0],SNR[0],MI[0],GMI[0]]
results = np.array([polx])

df2 = pd.DataFrame(results, index=['Pol. X'], columns=['BER', 'SER', 'SNR [dB]', 'GMI [bits]', 'MI [bits]'])
df2.style.format({"BER": "{:.2e}", "SER": "{:.2e}", "SNR [dB]": "{:.2f}", "GMI [bits]": "{:.2f}", "MI [bits]": "{:.2f}"})
# Out:
# <style type="text/css">
# </style>
# <table id="T_aa0d4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aa0d4_level0_col0" class="col_heading level0 col0" >BER</th>
#       <th id="T_aa0d4_level0_col1" class="col_heading level0 col1" >SER</th>
#       <th id="T_aa0d4_level0_col2" class="col_heading level0 col2" >SNR [dB]</th>
#       <th id="T_aa0d4_level0_col3" class="col_heading level0 col3" >GMI [bits]</th>
#       <th id="T_aa0d4_level0_col4" class="col_heading level0 col4" >MI [bits]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa0d4_level0_row0" class="row_heading level0 row0" >Pol. X</th>
#       <td id="T_aa0d4_row0_col0" class="data row0 col0" >1.45e-03</td>
#       <td id="T_aa0d4_row0_col1" class="data row0 col1" >8.47e-03</td>
#       <td id="T_aa0d4_row0_col2" class="data row0 col2" >23.15</td>
#       <td id="T_aa0d4_row0_col3" class="data row0 col3" >5.95</td>
#       <td id="T_aa0d4_row0_col4" class="data row0 col4" >5.95</td>
#     </tr>
#   </tbody>
# </table>

# %%
# # Salvar variáveis em arquivos externos
# import pickle

# if status_awgn == True:
#     flagAWGN = f'[{status_awgn}-{OSNRdB}]'
# else:
#     flagAWGN = '[False]'

# if paramRx.type == 'br':
#     flagRx = '[BR]'
# else:
#     flagRx = f'[SER-{paramRx.algSSBI.upper()}]'

# nameFile = f'\
# .\\{paramTx.M}QAM_\
# L-{paramCh.Ltotal}km_\
# AWGN-{flagAWGN}_\
# LOSPR-{LOSPR}dB_\
# Receiver-{flagRx}.pkl'

# status = {
#     'MQAM': paramTx.M,
#     'Distância': paramCh.Ltotal,
#     'AWGN': flagAWGN,
#     'LOSPR': LOSPR,
#     'Receiver': flagRx,
#     'SNR': SNR[0],
#     'BER': BER[0]
#     }

# with open(nameFile, 'wb') as arquivo:
#     pickle.dump(status, arquivo)
#     print(f'Arquivo {nameFile} criado!')
#     print(status)
