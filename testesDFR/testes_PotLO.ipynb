# %%
Plo_dBm = 5
print(f'Potência do LO: {Plo_dBm} dBm\n')
# %run "./main_testes_PotLO.ipynb"
# Out:
# Potência do LO: 5 dBm
#
# channel 0	 fc : 193.1000 THz
#   mode #0	 power: 0.00 dBm
# channel 0	 power: 0.00 dBm
#
# total WDM signal power: 0.00 dBm
# back-to-back connection.
# Local oscillator
#  - Power: 5.00 dBm
#  - LineWidth: 0.00 kHz
#  - Frequency offset: 0.00 MHz
# Pot_{sigPD-sigWDM} =  0.05029211026226428
# Pot_{sigDFR-sigWDM} =  0.050165807332734576
# Pot_{sigDFR-sigPD} =  3.1910525001738905e-05

# %%
Plo_dBm = Plo_dBm+4
print(f'Potência do LO: {Plo_dBm} dBm\n')
# %run "./main_testes_PotLO.ipynb"
# Out:
# Potência do LO: 9 dBm
#
# channel 0	 fc : 193.1000 THz
#   mode #0	 power: 0.00 dBm
# channel 0	 power: 0.00 dBm
#
# total WDM signal power: 0.00 dBm
# back-to-back connection.
# Local oscillator
#  - Power: 9.00 dBm
#  - LineWidth: 0.00 kHz
#  - Frequency offset: 0.00 MHz
# Pot_{sigPD-sigWDM} =  0.020429385224660247
# Pot_{sigDFR-sigWDM} =  0.020429385224660097
# Pot_{sigDFR-sigPD} =  5.246249700996558e-29

# %%
Plo_dBm = Plo_dBm+4
print(f'Potência do LO: {Plo_dBm} dBm\n')
# %run "./main_testes_PotLO.ipynb"
# Out:
# Potência do LO: 13 dBm
#
# channel 0	 fc : 193.1000 THz
#   mode #0	 power: 0.00 dBm
# channel 0	 power: 0.00 dBm
#
# total WDM signal power: 0.00 dBm
# back-to-back connection.
# Local oscillator
#  - Power: 13.00 dBm
#  - LineWidth: 0.00 kHz
#  - Frequency offset: 0.00 MHz
# Pot_{sigPD-sigWDM} =  0.008160111586607217
# Pot_{sigDFR-sigWDM} =  0.00816011158660729
# Pot_{sigDFR-sigPD} =  8.351017603654378e-29

# %%
Plo_dBm = Plo_dBm+4
print(f'Potência do LO: {Plo_dBm} dBm\n')
# %run "./main_testes_PotLO.ipynb"
# Out:
# Potência do LO: 17 dBm
#
# channel 0	 fc : 193.1000 THz
#   mode #0	 power: 0.00 dBm
# channel 0	 power: -0.00 dBm
#
# total WDM signal power: -0.00 dBm
# back-to-back connection.
# Local oscillator
#  - Power: 17.00 dBm
#  - LineWidth: 0.00 kHz
#  - Frequency offset: 0.00 MHz
# Pot_{sigPD-sigWDM} =  0.003277849846936345
# Pot_{sigDFR-sigWDM} =  0.0032778498469364487
# Pot_{sigDFR-sigPD} =  3.70683454841111e-28

# %%
Plo_dBm = Plo_dBm+4
print(f'Potência do LO: {Plo_dBm} dBm\n')
# %run "./main_testes_PotLO.ipynb"
# Out:
# Potência do LO: 21 dBm
#
# channel 0	 fc : 193.1000 THz
#   mode #0	 power: 0.00 dBm
# channel 0	 power: 0.00 dBm
#
# total WDM signal power: 0.00 dBm
# back-to-back connection.
# Local oscillator
#  - Power: 21.00 dBm
#  - LineWidth: 0.00 kHz
#  - Frequency offset: 0.00 MHz
# Pot_{sigPD-sigWDM} =  0.0013434303011907421
# Pot_{sigDFR-sigWDM} =  0.0013434303011906471
# Pot_{sigDFR-sigPD} =  1.5271323598229445e-28
