# %%
Rd = 1
print(f'Responsividade: {Rd} [A/W]\n')
# %run "./main_testes_Rd.ipynb"
# Out:
# Responsividade: 1 [A/W]
#
# channel 0	 fc : 193.1000 THz
#   mode #0	 power: 0.00 dBm
# channel 0	 power: -0.00 dBm
#
# total WDM signal power: -0.00 dBm
# back-to-back connection.
# Local oscillator
#  - Power: 20.00 dBm
#  - LineWidth: 0.00 kHz
#  - Frequency offset: 0.00 MHz
# Pot_{sigPD-sigWDM} =  0.0016340993954275312
# Pot_{sigDFR-sigWDM} =  0.0016340993954275021
# Pot_{sigDFR-sigPD} =  6.486001425803217e-29

# %%
Rd = 0.99
print(f'Responsividade: {Rd} [A/W]\n')
# %run "./main_testes_Rd.ipynb"
# Out:
# Responsividade: 0.99 [A/W]
#
# channel 0	 fc : 193.1000 THz
#   mode #0	 power: 0.00 dBm
# channel 0	 power: -0.00 dBm
#
# total WDM signal power: -0.00 dBm
# back-to-back connection.
# Local oscillator
#  - Power: 20.00 dBm
#  - LineWidth: 0.00 kHz
#  - Frequency offset: 0.00 MHz
# Pot_{sigPD-sigWDM} =  0.0016462910535040166
# Pot_{sigDFR-sigWDM} =  1.8812686035717554
# Pot_{sigDFR-sigPD} =  1.8826296447185966

# %%
Rd = 0.85
print(f'Responsividade: {Rd} [A/W]\n')
# %run "./main_testes_Rd.ipynb"
# Out:
# Responsividade: 0.85 [A/W]
#
# channel 0	 fc : 193.1000 THz
#   mode #0	 power: 0.00 dBm
# channel 0	 power: -0.00 dBm
#
# total WDM signal power: -0.00 dBm
# back-to-back connection.
# Local oscillator
#  - Power: 20.00 dBm
#  - LineWidth: 0.00 kHz
#  - Frequency offset: 0.00 MHz
# Pot_{sigPD-sigWDM} =  0.0016389862461062906
# Pot_{sigDFR-sigWDM} =  1.8453628738089407
# Pot_{sigDFR-sigPD} =  1.8482433536251532

# %%
Rd = 1.01
print(f'Responsividade: {Rd} [A/W]\n')
# %run "./main_testes_Rd.ipynb"
# Out:
# Responsividade: 1.01 [A/W]
#
# channel 0	 fc : 193.1000 THz
#   mode #0	 power: 0.00 dBm
# channel 0	 power: -0.00 dBm
#
# total WDM signal power: -0.00 dBm
# back-to-back connection.
# Local oscillator
#  - Power: 20.00 dBm
#  - LineWidth: 0.00 kHz
#  - Frequency offset: 0.00 MHz
# Pot_{sigPD-sigWDM} =  0.0016626807888671519
# Pot_{sigDFR-sigWDM} =  1.874697217422196
# Pot_{sigDFR-sigPD} =  1.8759440502255111

# %%
Rd = 1.15
print(f'Responsividade: {Rd} [A/W]\n')
# %run "./main_testes_Rd.ipynb"
# Out:
# Responsividade: 1.15 [A/W]
#
# channel 0	 fc : 193.1000 THz
#   mode #0	 power: 0.00 dBm
# channel 0	 power: 0.00 dBm
#
# total WDM signal power: 0.00 dBm
# back-to-back connection.
# Local oscillator
#  - Power: 20.00 dBm
#  - LineWidth: 0.00 kHz
#  - Frequency offset: 0.00 MHz
# Pot_{sigPD-sigWDM} =  0.0016200231306019695
# Pot_{sigDFR-sigWDM} =  1.8497890702943713
# Pot_{sigDFR-sigPD} =  1.8503923087522676
